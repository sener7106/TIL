# %%
import numpy as np
import pandas as pd

# %%
pre = pd.read_csv('C:/Users/user/Desktop/TodayLearn/TiL/Code/Project2/Projcet02/1_smart_card_data/data/smartcard20171019_before_Chained.csv', encoding = 'cp949')

# %%
pre.head(5)
# Out:
#                                       card_name route_id  on_area_name  \
# 0  ///21SEPKBIkPdYm7OoEueKbBc6ofbwm1NBBAZzBLJE=       버스  중앙대병원후문.흑석시장
# 1  ///21SEPKBIkPdYm7OoEueKbBc6ofbwm1NBBAZzBLJE=      지하철          봉은사역
# 2  ///21SEPKBIkPdYm7OoEueKbBc6ofbwm1NBBAZzBLJE=      지하철          봉은사역
# 3  ///2QD/Md5MfR4p3QONY4GuiEUA564xOSBfFb+wVlrU=       버스         시흥사거리
# 4  ///2QD/Md5MfR4p3QONY4GuiEUA564xOSBfFb+wVlrU=       버스          금천구청
#
#        on_lon     on_lat  on_dong  on_hour  on_minute  on_second  \
# 0  126.961720  37.506967  1120071       11         27         50
# 1  127.060265  37.514266  1123058       17         54         55
# 2  127.060265  37.514266  1123058       19         40         13
# 3  126.901570  37.452223  1118057       15         36          4
# 4  126.899065  37.459295  1118053       15         40          3
#
#   off_area_name     off_lon    off_lat  off_dong  off_hour  off_minute  \
# 0         중앙대후문  126.953575  37.505033   1120053        11          32
# ...

# %%
ls = list(set(list(pre['card_name'])))
